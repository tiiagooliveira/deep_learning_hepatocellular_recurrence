# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np 

#tcga_raw = pd.read_csv('/Volumes/HD_black⁩/⁨TCGA⁩/LIHC_matome.csv')

tcga_raw = pd.read_csv('LIHC_matome.csv')

# %%
print('Number of records:',tcga_raw.shape[0])
print('Number of features:',tcga_raw.shape[1])

print('Data types')
print(tcga_raw.dtypes)
# Out:
# Number of records: 371
# Number of features: 78
# Data types
# sample.id                                            object
# patient.id                                           object
# event                                                 int64
# OS                                                    int64
# ACVR2A                                                int64
# ALB                                                   int64
# APC                                                   int64
# APOB                                                  int64
# ARID1A                                                int64
# ARID1B                                                int64
# ARID2                                                 int64
# ASPM                                                  int64
# ATM                                                   int64
# ATP10B                                                int64
# AXIN1                                                 int64
# CCND1                                                 int64
# CCNE1                                                 int64
# CDKN2A                                                int64
# CTNNB1                                                int64
# CTNNBL1                                               int64
# DMD                                                   int64
# DOCK2                                                 int64
# DST                                                   int64
# ERRFI1                                                int64
# FAT4                                                  int64
# FGF19                                                 int64
# FGF3                                                  int64
# FRAS1                                                 int64
# FZD6                                                  int64
# GSK3B                                                 int64
#                                                      ...
# STAT3                                                 int64
# SYNE2                                                 int64
# TERT                                                  int64
# TP53                                                  int64
# TSC1                                                  int64
# TSC2                                                  int64
# VEGFA                                                 int64
# WNT1                                                  int64
# WNT5A                                                 int64
# adjacent_hepatic_tissue_inflammation_extent_type     object
# albumin_result_specified_value                      float64
# child_pugh_classification_grade                      object
# creatinine_value_in_mg_dl                           float64
# fetoprotein_outcome_value                           float64
# fibrosis_ishak_score                                 object
# hist_hepato_carc_fact                                object
# histological_type                                    object
# neoplasm_histologic_grade                            object
# pathologic_M                                         object
# pathologic_N                                         object
# pathologic_T                                         object
# platelet_result_count                               float64
# prothrombin_time_result_value                       float64
# total_bilirubin_upper_limit                         float64
# vascular_tumor_cell_type                             object
# viral_hepatitis_serology                             object
# tumor_stage.diagnoses                                object
# bmi.exposures                                       float64
# sample_type.samples                                  object
# TMB                                                   int64
# Length: 78, dtype: object

# %%
binary=[0,1]

for column in tcga_raw.columns[2:]:
    print(column)
    print('NA values:',tcga_raw.shape[0]-tcga_raw[column].count())
    if (tcga_raw[column].dtypes=='int64' and len((set(tcga_raw[column].unique())-set(binary)))!=0) or (tcga_raw[column].dtypes=='float'):
        print('Max:',tcga_raw[column].max())
        print('Min:',tcga_raw[column].min())
        print('Mean:',tcga_raw[column].mean())
        print('Var:',tcga_raw[column].var())
        print('Std:',tcga_raw[column].std())
        print('---------------------')      
    elif tcga_raw[column].dtypes=='int64' and len((set(tcga_raw[column].unique())-set(binary)))==0:
        print('Number of positives:',tcga_raw[column].tolist().count(1))
        print('Number of negatives:',tcga_raw[column].tolist().count(0))
        print('---------------------')
    else:    
        print('Mode:',tcga_raw[column].mode()[0])
        print('---------------------')
# Out:
# event
# NA values: 0
# Number of positives: 132
# Number of negatives: 239
# ---------------------
# OS
# NA values: 0
# Max: 3675
# Min: 1
# Mean: 821.3342318059299
# Var: 531022.828527719
# Std: 728.7131318479989
# ---------------------
# ACVR2A
# NA values: 0
# Number of positives: 13
# Number of negatives: 358
# ---------------------
# ALB
# NA values: 0
# Number of positives: 39
# Number of negatives: 332
# ---------------------
# APC
# NA values: 0
# Number of positives: 14
# Number of negatives: 357
# ---------------------
# APOB
# NA values: 0
# Number of positives: 34
# Number of negatives: 337
# ---------------------
# ARID1A
# NA values: 0
# Number of positives: 21
# Number of negatives: 350
# ---------------------
# ARID1B
# NA values: 0
# Number of positives: 10
# Number of negatives: 361
# ---------------------
# ARID2
# NA values: 0
# Number of positives: 21
# Number of negatives: 350
# ---------------------
# ASPM
# NA values: 0
# Number of positives: 9
# Number of negatives: 362
# ---------------------
# ATM
# NA values: 0
# Number of positives: 10
# Number of negatives: 361
# ---------------------
# ATP10B
# NA values: 0
# Number of positives: 12
# Number of negatives: 359
# ---------------------
# AXIN1
# NA values: 0
# Number of positives: 26
# Number of negatives: 345
# ---------------------
# CCND1
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# CCNE1
# NA values: 0
# Number of positives: 0
# Number of negatives: 371
# ---------------------
# CDKN2A
# NA values: 0
# Number of positives: 11
# Number of negatives: 360
# ---------------------
# CTNNB1
# NA values: 0
# Number of positives: 83
# Number of negatives: 288
# ---------------------
# CTNNBL1
# NA values: 0
# Number of positives: 5
# Number of negatives: 366
# ---------------------
# DMD
# NA values: 0
# Number of positives: 24
# Number of negatives: 347
# ---------------------
# DOCK2
# NA values: 0
# Number of positives: 26
# Number of negatives: 345
# ---------------------
# DST
# NA values: 0
# Number of positives: 23
# Number of negatives: 348
# ---------------------
# ERRFI1
# NA values: 0
# Number of positives: 4
# Number of negatives: 367
# ---------------------
# FAT4
# NA values: 0
# Number of positives: 14
# Number of negatives: 357
# ---------------------
# FGF19
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# FGF3
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# FRAS1
# NA values: 0
# Number of positives: 21
# Number of negatives: 350
# ---------------------
# FZD6
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# GSK3B
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# HNF1A
# NA values: 0
# Number of positives: 8
# Number of negatives: 363
# ---------------------
# HNF1B
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# IL6ST
# NA values: 0
# Number of positives: 9
# Number of negatives: 362
# ---------------------
# IRF2
# NA values: 0
# Number of positives: 4
# Number of negatives: 367
# ---------------------
# JAK1
# NA values: 0
# Number of positives: 8
# Number of negatives: 363
# ---------------------
# JAK2
# NA values: 0
# Number of positives: 5
# Number of negatives: 366
# ---------------------
# KEAP1
# NA values: 0
# Number of positives: 15
# Number of negatives: 356
# ---------------------
# KIT
# NA values: 0
# Number of positives: 13
# Number of negatives: 358
# ---------------------
# KMT2A
# NA values: 0
# Number of positives: 13
# Number of negatives: 358
# ---------------------
# KMT2D
# NA values: 0
# Number of positives: 23
# Number of negatives: 348
# ---------------------
# MAP1B
# NA values: 0
# Number of positives: 12
# Number of negatives: 359
# ---------------------
# NAV3
# NA values: 0
# Number of positives: 11
# Number of negatives: 360
# ---------------------
# NFE2L2
# NA values: 0
# Number of positives: 7
# Number of negatives: 364
# ---------------------
# PEG3
# NA values: 0
# Number of positives: 6
# Number of negatives: 365
# ---------------------
# PIK3CA
# NA values: 0
# Number of positives: 10
# Number of negatives: 361
# ---------------------
# PTPRB
# NA values: 0
# Number of positives: 17
# Number of negatives: 354
# ---------------------
# RB1
# NA values: 0
# Number of positives: 16
# Number of negatives: 355
# ---------------------
# RPS6KA3
# NA values: 0
# Number of positives: 14
# Number of negatives: 357
# ---------------------
# STAT3
# NA values: 0
# Number of positives: 6
# Number of negatives: 365
# ---------------------
# SYNE2
# NA values: 0
# Number of positives: 15
# Number of negatives: 356
# ---------------------
# TERT
# NA values: 0
# Number of positives: 5
# Number of negatives: 366
# ---------------------
# TP53
# NA values: 0
# Number of positives: 98
# Number of negatives: 273
# ---------------------
# TSC1
# NA values: 0
# Number of positives: 7
# Number of negatives: 364
# ---------------------
# TSC2
# NA values: 0
# Number of positives: 10
# Number of negatives: 361
# ---------------------
# VEGFA
# NA values: 0
# Number of positives: 1
# Number of negatives: 370
# ---------------------
# WNT1
# NA values: 0
# Number of positives: 4
# Number of negatives: 367
# ---------------------
# WNT5A
# NA values: 0
# Number of positives: 2
# Number of negatives: 369
# ---------------------
# adjacent_hepatic_tissue_inflammation_extent_type
# NA values: 134
# Mode: None
# ---------------------
# albumin_result_specified_value
# NA values: 69
# Max: 5200.0
# Min: 0.2
# Mean: 21.531456953642376
# Var: 89411.78615002976
# Std: 299.0180364961782
# ---------------------
# child_pugh_classification_grade
# NA values: 127
# Mode: A
# ---------------------
# creatinine_value_in_mg_dl
# NA values: 67
# Max: 124.0
# Min: 0.4
# Mean: 2.742105263157897
# Var: 137.05940941462572
# Std: 11.707237480064446
# ---------------------
# fetoprotein_outcome_value
# NA values: 89
# Max: 2035400.0
# Min: 1.0
# Mean: 13241.801418439716
# Var: 15460793706.871456
# Std: 124341.44002251003
# ---------------------
# fibrosis_ishak_score
# NA values: 156
# Mode: 0 - No Fibrosis
# ---------------------
# hist_hepato_carc_fact
# NA values: 18
# Mode: Hepatitis B
# ---------------------
# histological_type
# NA values: 0
# Mode: Hepatocellular Carcinoma
# ---------------------
# neoplasm_histologic_grade
# NA values: 5
# Mode: G2
# ---------------------
# pathologic_M
# NA values: 0
# Mode: M0
# ---------------------
# pathologic_N
# NA values: 1
# Mode: N0
# ---------------------
# pathologic_T
# NA values: 2
# Mode: T1
# ---------------------
# platelet_result_count
# NA values: 62
# Max: 608000.0
# Min: 4000.0
# Mean: 218809.06148867315
# Var: 10045434203.337126
# Std: 100226.91356784926
# ---------------------
# prothrombin_time_result_value
# NA values: 72
# Max: 36.4
# Min: 0.8
# Mean: 4.048494983277595
# Var: 24.28814370047809
# Std: 4.928300285136661
# ---------------------
# total_bilirubin_upper_limit
# NA values: 70
# Max: 21.0
# Min: 0.8
# Mean: 1.4122923588039842
# Var: 3.5819483942414143
# Std: 1.892603601983631
# ---------------------
# vascular_tumor_cell_type
# NA values: 54
# Mode: None
# ---------------------
# viral_hepatitis_serology
# NA values: 207
# Mode: Hepatitis B Surface Antigen
# ---------------------
# tumor_stage.diagnoses
# NA values: 0
# Mode: stage i
# ---------------------
# bmi.exposures
# NA values: 33
# Max: 131.8359375
# Min: 14.526643990899998
# Mean: 26.151499045631375
# Var: 70.87850183545109
# Std: 8.418937096537253
# ---------------------
# sample_type.samples
# NA values: 0
# Mode: Primary Tumor
# ---------------------
# TMB
# NA values: 0
# Max: 12
# Min: 0
# Mean: 2.0619946091644206
# Var: 3.6366868215924817
# Std: 1.907009916490337
# ---------------------

# %%
imp = SimpleImputer(missing_values=np.nan,strategy='mean')
